# %% [markdown]
# <a href="https://colab.research.google.com/github/HadBdB/ECM_DDEFI_2526_Cours1/blob/main/Exemple%20novembre.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Quel package utilisé pour le biais vs la variance
# Usuellement on a pandas, numpy, matplotlib, seaborn et scikitlearn

# !pip install scikit-learn numpy matplotlib seaborn

# %%
# Bloc des import

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Sachez que certains packages ont des datasets sauvegardés
#Sci kit learn à celui des housing californiens
from sklearn.datasets import fetch_california_housing
from sklearn.model_selection import train_test_split, learning_curve
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.linear_model import LinearRegression
