# %% [markdown]
# <a href="https://colab.research.google.com/github/HadBdB/ECM_DDEFI_2526_Cours1/blob/main/Ex_cours_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello Centrale Med")
# Out:
# Hello Centrale Med

# %%
# Variables
a = "Alice"
height = 1.85
is_student = True

# %%
height
# Out:
# 1.85

# %%
print(f"{a} mesure {height} m et est une étudiante {is_student}")
# Out:
# Alice mesure 1.85 m et est une étudiante True

# %%
# !pip install numpy
# !pip install pandas
